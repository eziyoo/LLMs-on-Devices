# %%
# Step 1: Load and save the dataset
from datasets import load_dataset

# %%
# Load IMDb
dataset = load_dataset("imdb")

# %%
# Save to CSV
dataset["train"].to_csv("Dataset/IMDb dataset/imdb_train.csv", index=False)
dataset["test"].to_csv("Dataset/IMDb dataset/imdb_test.csv", index=False)
# Out:
# ...
# Creating CSV from Arrow format:   0%|          | 0/25 [00:00<?, ?ba/s]
# 32565148

# %%
# Show metadata: features, size, etc.
print(dataset["train"].features)
print(f"Train size: {len(dataset['train'])}")
print(f"Test size: {len(dataset['test'])}")
# Out:
# {'text': Value(dtype='string', id=None), 'label': ClassLabel(names=['neg', 'pos'], id=None)}
# Train size: 25000
# Test size: 25000
